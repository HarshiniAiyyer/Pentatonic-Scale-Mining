# %% [markdown]
# ## PART 2 - MINING AND CLASSIFICATION

# %%
# !pip install mlxtend
# !pip install prefixspan
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for prefixspan: filename=prefixspan-0.5.2-py3-none-any.whl size=11239 sha256=fab39cabb00352917f2e50ac9f650206f1099677bacf83d48c1bbc40d157f013
#   Stored in directory: /root/.cache/pip/wheels/1b/96/e2/4eafa983829d97cbdd88d66b06221e28a35ff5b8c618c9910d
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13721 sha256=2f54b299b3df96c291a8ce3f9bc44c78ebf9313a02c620f240ade3073b782d92
#   Stored in directory: /root/.cache/pip/wheels/70/4a/46/1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
# ...

# %%
# import necessary libraries
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

data = pd.read_csv('/content/res (1).csv')
data.head()
# Out:
#       110     196  261.63  130.81   110.1   196.1  130.81.1  261.63.1     220  \
# 0  329.63  293.66  164.81  293.66  329.63  293.66    329.63    293.66  164.81
# 1  130.81  329.63  329.63  329.63  261.63  329.63    164.81    164.81  261.63
# 2  164.81  329.63  110.00  196.00  329.63  164.81    110.00    196.00  329.63
# 3  164.81  293.66  261.63  146.83  329.63  293.66    261.63    146.83  164.81
# 4  130.81  130.81  261.63  293.66  130.81  130.81    130.81    146.83  261.63
#
#     196.2  ...   220.1   196.4  261.63.3  261.63.4  130.81.7   220.2   110.3  \
# 0  293.66  ...  329.63  293.66    164.81    146.83    130.81  164.81  329.63
# 1  164.81  ...  261.63  329.63    329.63    329.63    261.63  130.81  261.63
# 2  329.63  ...  329.63  329.63    220.00    196.00       110  164.81  164.81
# 3  146.83  ...  329.63  146.83    130.81    293.66       220  329.63  164.81
# 4  130.81  ...  261.63  261.63    130.81    146.83    146.83  130.81  261.63
#
#     196.5   196.6  P
# ...

# %% [markdown]
# ### (1) Data Mining Algorithm
#
# I am planning to use PrefixSpan algorithm

# %% [markdown]
# ### Apriori

# %%
# Import the PrefixSpan algorithm from the prefixspan library
from prefixspan import PrefixSpan

# %%
df = pd.read_csv('/content/df2 (1).csv')
df.head()
# Out:
#                                    D', 'P', 'S', 'S'
# 0  G', 'R', 'G', 'R', 'S', 'R', 'S', 'R', 'S', 'G...
# 1                                  S', 'G', 'G', 'G'
# 2                             G', 'G', 'D', 'P', 'D'
# 3                             G', 'R', 'S', 'R', 'D'
# 4  S', 'S', 'S', 'R', 'R', 'G', 'G', 'P', 'P', 'D...

# %%
# convert to list using tolist()
df_list = df.values.tolist()
print(df_list)
# Out:
# [["G', 'R', 'G', 'R', 'S', 'R', 'S', 'R', 'S', 'G', 'R', 'G', 'S', 'R'"], ["S', 'G', 'G', 'G'"], ["G', 'G', 'D', 'P', 'D'"], ["G', 'R', 'S', 'R', 'D'"], ["S', 'S', 'S', 'R', 'R', 'G', 'G', 'P', 'P', 'D', 'D'"], ["G', 'P', 'G', 'G', 'R', 'S', 'R', 'G', 'R', 'R', 'S', 'D', 'S', 'R', 'G', 'R'"], ["G', 'R', 'G', 'R', 'S', 'R', 'S', 'R', 'S', 'G', 'R', 'G', 'S', 'R'"], ["G', 'R', 'S', 'R', 'D'"], ["G', 'G', 'D', 'P', 'G'"], ["G', 'G', 'D', 'D', 'P', 'G', 'G', 'D', 'P', 'G', 'P', 'G', 'R', 'S', 'R'"], ["S', 'R', 'G', 'R', 'S', 'R', 'S', 'D', 'S', 'R', 'G', 'P', 'G', 'R', 'S', 'R'"], ["R', 'D', 'S', 'R', 'G', 'R'"], ["D', 'S', 'R', 'S', 'D', 'P', 'D', 'S', 'D', 'P', 'G', 'R', 'S', 'R'"], ["D', 'S', 'R', 'S', 'D', 'P', 'D', 'S', 'D', 'P', 'G', 'R', 'S', 'R'"], ["S', 'G', 'G', 'G'"], ["G', 'P', 'D', 'P', 'D', 'S', 'R', 'G', 'R', 'G', 'S', 'R', 'D'"], ["D', 'P', 'G', 'G', 'R'"], ["G', 'G', 'R', 'S', 'S', 'R', 'R', 'G', 'G', 'R', 'R'"], ["D', 'S', 'D', 'D', 'D', 'P'"], ["D', 'S', 'D', 'D', 'D',
# ...

# %%
# Create an instance of the PrefixSpan algorithm
ps = PrefixSpan(df_list)

# Find frequent sequential patterns with a minimum support of 2
patterns = ps.frequent(2)

# Print the frequent sequential patterns
for pattern in patterns:
    print(pattern)
# Out:
# (7, ["G', 'R', 'G', 'R', 'S', 'R', 'S', 'R', 'S', 'G', 'R', 'G', 'S', 'R'"])
# (7, ["S', 'G', 'G', 'G'"])
# (7, ["G', 'G', 'D', 'P', 'D'"])
# (7, ["G', 'R', 'S', 'R', 'D'"])
# (7, ["S', 'S', 'S', 'R', 'R', 'G', 'G', 'P', 'P', 'D', 'D'"])
# (7, ["G', 'P', 'G', 'G', 'R', 'S', 'R', 'G', 'R', 'R', 'S', 'D', 'S', 'R', 'G', 'R'"])
# (7, ["G', 'G', 'D', 'P', 'G'"])
# (7, ["G', 'G', 'D', 'D', 'P', 'G', 'G', 'D', 'P', 'G', 'P', 'G', 'R', 'S', 'R'"])
# (7, ["S', 'R', 'G', 'R', 'S', 'R', 'S', 'D', 'S', 'R', 'G', 'P', 'G', 'R', 'S', 'R'"])
# (7, ["R', 'D', 'S', 'R', 'G', 'R'"])
# (7, ["D', 'S', 'R', 'S', 'D', 'P', 'D', 'S', 'D', 'P', 'G', 'R', 'S', 'R'"])
# (7, ["G', 'P', 'D', 'P', 'D', 'S', 'R', 'G', 'R', 'G', 'S', 'R', 'D'"])
# (14, ["D', 'P', 'G', 'G', 'R'"])
# (7, ["G', 'G', 'R', 'S', 'S', 'R', 'R', 'G', 'G', 'R', 'R'"])
# (7, ["D', 'S', 'D', 'D', 'D', 'P'"])
# (7, ["G', 'G', 'P', 'P', 'D', 'P', 'D', 'S', 'D', 'S', 'R', 'S', 'G', 'R', 'S'"])
# ...

# %% [markdown]
# (2) Classification algorithm
#
# SVM Algorithm

# %%
# Import the necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Load the dataset into a pandas DataFrame
import pandas as pd
data = pd.read_csv('/content/res.csv',header = 0)

data.head()
# Out:
#    Note_1  Note_2  Note_3  Note_4  Note_5  Note_6  Note_7  Note_8  Note_9  \
# 0  110.00  196.00  261.63  130.81  110.00  196.00  130.81  261.63  220.00
# 1  329.63  293.66  164.81  293.66  329.63  293.66  329.63  293.66  164.81
# 2  130.81  329.63  329.63  329.63  261.63  329.63  164.81  164.81  261.63
# 3  164.81  329.63  110.00  196.00  329.63  164.81  110.00  196.00  329.63
# 4  164.81  293.66  261.63  146.83  329.63  293.66  261.63  146.83  164.81
#
#    Note_10  ...  Note_18  Note_19  Note_20  Note_21  Note_22  Note_23  \
# 0   196.00  ...   130.81   220.00   196.00   261.63   261.63   130.81
# 1   293.66  ...   293.66   329.63   293.66   164.81   146.83   130.81
# 2   164.81  ...   329.63   261.63   329.63   329.63   329.63   261.63
# 3   329.63  ...   196.00   329.63   329.63   220.00   196.00   110.00
# 4   146.83  ...   146.83   329.63   146.83   130.81   293.66   220.00
#
#    Note_24  Note_25  Note_26  Note
# 0   220.00   110.00   196.00     P
# ...

# %%
type(data["Note"])
# Out:
# pandas.core.series.Series

# %%
# Replace missing values with the mean value of the column
data = data.fillna(data.mean())
# Out:
# <ipython-input-29-85f7bc2b9a1e>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data = data.fillna(data.mean())

# %%
data.head()
# Out:
#    Note_1  Note_2  Note_3  Note_4  Note_5  Note_6  Note_7  Note_8  Note_9  \
# 0  110.00  196.00  261.63  130.81  110.00  196.00  130.81  261.63  220.00
# 1  329.63  293.66  164.81  293.66  329.63  293.66  329.63  293.66  164.81
# 2  130.81  329.63  329.63  329.63  261.63  329.63  164.81  164.81  261.63
# 3  164.81  329.63  110.00  196.00  329.63  164.81  110.00  196.00  329.63
# 4  164.81  293.66  261.63  146.83  329.63  293.66  261.63  146.83  164.81
#
#    Note_10  ...  Note_18  Note_19  Note_20  Note_21  Note_22  Note_23  \
# 0   196.00  ...   130.81   220.00   196.00   261.63   261.63   130.81
# 1   293.66  ...   293.66   329.63   293.66   164.81   146.83   130.81
# 2   164.81  ...   329.63   261.63   329.63   329.63   329.63   261.63
# 3   329.63  ...   196.00   329.63   329.63   220.00   196.00   110.00
# 4   146.83  ...   146.83   329.63   146.83   130.81   293.66   220.00
#
#    Note_24  Note_25  Note_26  Note
# 0   220.00   110.00   196.00     P
# ...

# %%
# Replace empty spaces and null values with NaN
data = data.replace(r'^\s*$', np.nan, regex=True)
data = data.dropna()

# Replace remaining null values with column median
data = data.fillna(data.median())

# Print the updated dataset
print(data)
# Out:
#      Note_1  Note_2  Note_3  Note_4  Note_5  Note_6  Note_7  Note_8  Note_9  \
# 0    110.00  196.00  261.63  130.81  110.00  196.00  130.81  261.63  220.00
# 1    329.63  293.66  164.81  293.66  329.63  293.66  329.63  293.66  164.81
# 2    130.81  329.63  329.63  329.63  261.63  329.63  164.81  164.81  261.63
# 3    164.81  329.63  110.00  196.00  329.63  164.81  110.00  196.00  329.63
# 4    164.81  293.66  261.63  146.83  329.63  293.66  261.63  146.83  164.81
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 260  261.63  196.00  110.00  130.81  130.81  196.00  110.00  130.81  130.81
# 261  220.00  196.00  164.81  164.81  220.00  196.00  329.63  329.63  220.00
# 262  110.00  196.00  164.81  329.63  110.00  196.00  164.81  329.63  220.00
# 263  329.63  164.81  293.66  261.63  329.63  329.63  146.83  130.81  164.81
# 264  110.00  261.63  220.00  110.00  220.00  130.81  220.00  220.00  110.00
#
# ...

# %%
data.shape
# Out:
# (252, 27)

# %%
data = pd.concat([data] * 7, ignore_index=True)

data.shape
# Out:
# (1764, 27)

# %%
# shuffle the values within each row
for i in range(len(data)):
  if(i%3 == 0):
    np.random.shuffle(data.iloc[i].values)

data.head()
# Out:
#    Note_1  Note_2  Note_3  Note_4  Note_5  Note_6  Note_7  Note_8  Note_9  \
# 0  110.00  196.00  261.63  130.81  110.00  196.00  130.81  261.63  220.00
# 1  329.63  293.66  164.81  293.66  329.63  293.66  329.63  293.66  164.81
# 2  130.81  329.63  329.63  329.63  261.63  329.63  164.81  164.81  261.63
# 3  164.81  329.63  110.00  196.00  329.63  164.81  110.00  196.00  329.63
# 4  164.81  293.66  261.63  146.83  329.63  293.66  261.63  146.83  164.81
#
#    Note_10  ...  Note_18  Note_19  Note_20  Note_21  Note_22  Note_23  \
# 0   196.00  ...   130.81   220.00   196.00   261.63   261.63   130.81
# 1   293.66  ...   293.66   329.63   293.66   164.81   146.83   130.81
# 2   164.81  ...   329.63   261.63   329.63   329.63   329.63   261.63
# 3   329.63  ...   196.00   329.63   329.63   220.00   196.00   110.00
# 4   146.83  ...   146.83   329.63   146.83   130.81   293.66   220.00
#
#    Note_24  Note_25  Note_26  Note
# 0   220.00   110.00   196.00     P
# ...

# %%
# Convert the "Note" column into numeric format
le = LabelEncoder()
data["Note"] = le.fit_transform(data["Note"])

# %%
# Split the dataset into training and testing sets
x = data.iloc[:, :-1]
y = data.iloc[:, -1]
x = np.array(x)
y = np.array(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier


# create a list of classifiers
classifiers = [
    DecisionTreeClassifier(random_state=42),
    RandomForestClassifier(random_state=42),
    GradientBoostingClassifier(random_state = 42),
    MLPClassifier(random_state = 42),
    SVC(random_state=42)

]

# iterate over classifiers and fit them to the training data
for clf in classifiers:
    clf.fit(x_train, y_train)
    y_pred = clf.predict(x_test)
    print("Classifier:", clf.__class__.__name__)
    print("Classification Report - None Average")
    print(classification_report(y_test, y_pred))
# Out:
# Classifier: DecisionTreeClassifier
# Classification Report - None Average
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       117
#            1       1.00      1.00      1.00       141
#            2       1.00      1.00      1.00       293
#            3       1.00      1.00      1.00        77
#            4       1.00      1.00      1.00        78
#
#     accuracy                           1.00       706
#    macro avg       1.00      1.00      1.00       706
# weighted avg       1.00      1.00      1.00       706
#
# Classifier: RandomForestClassifier
# Classification Report - None Average
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       117
#            1       1.00      1.00      1.00       141
#            2       1.00      1.00      1.00       293
#            3       1.00      1.00      1.00        77
#            4       1.00      1.00      1.00        78
# ...

# %% [markdown]
# ### All evaluation metrics : 1? 😯
#
# For a dataset built from scratch?
